# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install anvil-uplink
# Out:
# Requirement already satisfied: anvil-uplink in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Collecting argparse (from anvil-uplink)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from anvil-uplink) (0.18.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anvil-uplink) (1.16.0)
# Requirement already satisfied: ws4py in /usr/local/lib/python3.10/dist-packages (from anvil-uplink) (0.5.1)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import anvil.server
anvil.server.connect("FDFLEPPVIGZFNLYADVFLX4JQ-ZHXYWRBKP6XZYK2Q")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Development" as SERVER

# %%
# pip install tensorflow keras pickle nltk
from google.colab import drive
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('/content/drive/MyDrive/Chatbot/intents.json').read()
intents = json.loads(intents_file)

# %%
import nltk
nltk.download('punkt')
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        documents.append((word, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['what', "'s", 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['How', "'s", 'the', 'day', 'treating', 'you', 'so', 'far', '?'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['let', "'s", 'not', 'talk'], 'goodbye'), (['I', 'do', "n't", 'want', 'to', 'talk', 'to', 'you'], 'goodbye'), (['Who', 'is', 'your', 'creator'], 'creation'), (['Who', 'made', 'you'], 'creation'), (['who', 'built', 'you'], 'creation'), (['how', 'old', 'are', 'you', '?'], 'age'), (['what', 'is', 'your', 'age', '?'], 'age'), (['whats', 'your', 'age', '?'], 'age'), (['when', 'do', 'you', 'celebrate', 'your', 'birthday', '?'], 'age'), (['how', 'old', 'is', 'your', 'platform'], 'age'), (['ha', 'ha', 'ha', 'ha'], 'e_haha'), (['haha', 'haha', 'haha'], 'e_haha'), (['laughing', 'out'], 'e_haha'), (['hehehe'], 'e_haha'), (['ah', 'ah', 'ah'], 'e_haha'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'yes'), (['Yeah'], 'yes'), (['Amazing'], 'yes'), (['Haha', 'yep'], 'yes'), (['fine'], 'yes'), (['yes'], 'yes'), (['Indeed'], 'yes'), (['Yup'], 'yes'), (['yep'], 'yes'), (['Oh', 'really'], 'yes'), (['Okay'], 'yes'), (['Okie'], 'yes'), (['Ok'], 'yes'), (['I', 'see'], 'yes'), (['why'], 'why'), (['what'], 'why'), (['whats', 'that'], 'why'), (['no'], 'no'), (['nah'], 'no'), (['not', 'really'], 'no'), (['thats', 'scary'], 'no'), (['singularity'], 'no'), (['what', 'are', 'you', 'doing', 'now', '?'], 'what_are_you_doing'), (['What', 'are', 'you', 'doing', '?'], 'what_are_you_doing'), (['what', 'you', 'doin'], 'what_are_you_doing'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['what', 'are', 'you', 'doing'], 'how_are_you'), (['fuck'], 'abusive'), (['fuck', 'you'], 'abusive'), (['fuck', 'off'], 'abusive'), (['fuck', 'yourself'], 'abusive'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['break'], 'doing_badly'), (['depressed'], 'doing_badly'), (['depression'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['I', 'love', 'to', 'watch', 'netflix'], 'netflix'), (['I', 'love', 'netflix', 'and', 'chill'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['are', 'you', 'real'], 'real_bot'), (['are', 'you', 'human'], 'real_bot'), (['are', 'you', 'a', 'robot'], 'real_bot'), (['are', 'you', 'alive'], 'real_bot'), (['are', 'you', 'sentient'], 'real_bot'), (['are', 'you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['yeah', 'sure', 'tell', 'me'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['how', 'about', 'another', 'one'], 'joke'), (['joke'], 'joke'), (['cheer', 'me', 'up'], 'joke'), (['make', 'me', 'happy'], 'joke'), (['can', 'you' ...

# %%
import nltk
nltk.download('wordnet')
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words

    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Training data is created
# <ipython-input-7-9d5961342cb0>:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# deep neural networks model
import tensorflow as tf
epochs = 200
learning_rate = 0.01
decay_rate = learning_rate / epochs
optimizer = tf.keras.optimizers.legacy.Adam(lr=learning_rate, decay=decay_rate)
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#Training and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 31/31 [==============================] - 1s 2ms/step - loss: 3.6949 - accuracy: 0.1053
# Epoch 2/200
# 31/31 [==============================] - 0s 2ms/step - loss: 3.0472 - accuracy: 0.1645
# Epoch 3/200
# 31/31 [==============================] - 0s 1ms/step - loss: 2.6967 - accuracy: 0.2237
# Epoch 4/200
# 31/31 [==============================] - 0s 1ms/step - loss: 2.6188 - accuracy: 0.3289
# Epoch 5/200
# 31/31 [==============================] - 0s 10ms/step - loss: 2.6160 - accuracy: 0.2895
# Epoch 6/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.2882 - accuracy: 0.3684
# Epoch 7/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.3300 - accuracy: 0.3882
# Epoch 8/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.0940 - accuracy: 0.4605
# Epoch 9/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.0017 - accuracy: 0.3947
# Epoch 10/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.0163 - accuracy: 0.4013
# Epoch 11/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.1789 - accuracy: 0.4211
# Epoch 12/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7976 - accuracy: 0.5197
# Epoch 13/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.9349 - accuracy: 0.4737
# Epoch 14/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.0275 - accuracy: 0.4868
# Epoch 15/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7604 - accuracy: 0.4737
# Epoch 16/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7203 - accuracy: 0.5395
# Epoch 17/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.8963 - accuracy: 0.5263
# Epoch 18/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.8833 - accuracy: 0.4605
# Epoch 19/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7181 - accuracy: 0.5395
# Epoch 20/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.8250 - accuracy: 0.5724
# Epoch 21/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.2298 - accuracy: 0.4539
# Epoch 22/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6386 - accuracy: 0.5724
# Epoch 23/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6522 - accuracy: 0.5789
# Epoch 24/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.7338 - accuracy: 0.5789
# Epoch 25/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4896 - accuracy: 0.6053
# Epoch 26/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4339 - accuracy: 0.5855
# Epoch 27/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.5477 - accuracy: 0.5461
# Epoch 28/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2726 - accuracy: 0.6250
# Epoch 29/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3266 - accuracy: 0.6118
# Epoch 30/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.7485 - accuracy: 0.6316
# Epoch 31/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4819 - accuracy: 0.5987
# Epoch 32/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3788 - accuracy: 0.5855
# Epoch 33/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2660 - accuracy: 0.6250
# Epoch 34/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5731 - accuracy: 0.5789
# Epoch 35/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1796 - accuracy: 0.6250
# Epoch 36/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2984 - accuracy: 0.5921
# Epoch 37/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3969 - accuracy: 0.6184
# Epoch 38/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2122 - accuracy: 0.6184
# Epoch 39/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1835 - accuracy: 0.6316
# Epoch 40/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5332 - accuracy: 0.5921
# Epoch 41/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4831 - accuracy: 0.5921
# Epoch 42/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5001 - accuracy: 0.6184
# Epoch 43/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3093 - accuracy: 0.6118
# Epoch 44/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1992 - accuracy: 0.6316
# Epoch 45/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6803 - accuracy: 0.6053
# Epoch 46/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3486 - accuracy: 0.6382
# Epoch 47/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.3611 - accuracy: 0.6118
# Epoch 48/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3472 - accuracy: 0.6053
# Epoch 49/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2779 - accuracy: 0.6250
# Epoch 50/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.9752 - accuracy: 0.7303
# Epoch 51/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2350 - accuracy: 0.6513
# Epoch 52/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2822 - accuracy: 0.5855
# Epoch 53/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2426 - accuracy: 0.6776
# Epoch 54/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.3391 - accuracy: 0.6118
# Epoch 55/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2025 - accuracy: 0.6579
# Epoch 56/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0316 - accuracy: 0.6842
# Epoch 57/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.0794 - accuracy: 0.6579
# Epoch 58/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1828 - accuracy: 0.6513
# Epoch 59/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3605 - accuracy: 0.6447
# Epoch 60/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0698 - accuracy: 0.6513
# Epoch 61/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3379 - accuracy: 0.6316
# Epoch 62/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3113 - accuracy: 0.6053
# Epoch 63/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3435 - accuracy: 0.6579
# Epoch 64/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.1852 - accuracy: 0.6513
# Epoch 65/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4064 - accuracy: 0.6250
# Epoch 66/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.3841 - accuracy: 0.6250
# Epoch 67/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.2280 - accuracy: 0.6579
# Epoch 68/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3275 - accuracy: 0.6250
# Epoch 69/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3103 - accuracy: 0.6382
# Epoch 70/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3473 - accuracy: 0.6184
# Epoch 71/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.2780 - accuracy: 0.5987
# Epoch 72/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.5488 - accuracy: 0.5658
# Epoch 73/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0832 - accuracy: 0.6579
# Epoch 74/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3854 - accuracy: 0.6250
# Epoch 75/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3804 - accuracy: 0.6447
# Epoch 76/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4753 - accuracy: 0.5855
# Epoch 77/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3387 - accuracy: 0.6382
# Epoch 78/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2976 - accuracy: 0.6447
# Epoch 79/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3198 - accuracy: 0.6382
# Epoch 80/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.4051 - accuracy: 0.6184
# Epoch 81/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1746 - accuracy: 0.6645
# Epoch 82/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2712 - accuracy: 0.6316
# Epoch 83/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0796 - accuracy: 0.6776
# Epoch 84/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1737 - accuracy: 0.6513
# Epoch 85/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5266 - accuracy: 0.6513
# Epoch 86/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2498 - accuracy: 0.7039
# Epoch 87/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3414 - accuracy: 0.6316
# Epoch 88/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2438 - accuracy: 0.5987
# Epoch 89/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2921 - accuracy: 0.6579
# Epoch 90/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0262 - accuracy: 0.6711
# Epoch 91/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6625 - accuracy: 0.6579
# Epoch 92/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1007 - accuracy: 0.6711
# Epoch 93/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3569 - accuracy: 0.6645
# Epoch 94/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1754 - accuracy: 0.6513
# Epoch 95/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2801 - accuracy: 0.6447
# Epoch 96/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1498 - accuracy: 0.6842
# Epoch 97/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0439 - accuracy: 0.6974
# Epoch 98/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1953 - accuracy: 0.6447
# Epoch 99/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2621 - accuracy: 0.6184
# Epoch 100/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1019 - accuracy: 0.6579
# Epoch 101/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2825 - accuracy: 0.6513
# Epoch 102/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9685 - accuracy: 0.6974
# Epoch 103/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1958 - accuracy: 0.6579
# Epoch 104/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0944 - accuracy: 0.7105
# Epoch 105/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1897 - accuracy: 0.6316
# Epoch 106/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2037 - accuracy: 0.6579
# Epoch 107/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8885 - accuracy: 0.7237
# Epoch 108/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3260 - accuracy: 0.6316
# Epoch 109/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4773 - accuracy: 0.6316
# Epoch 110/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0089 - accuracy: 0.6711
# Epoch 111/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0387 - accuracy: 0.6842
# Epoch 112/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2614 - accuracy: 0.7171
# Epoch 113/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2865 - accuracy: 0.6645
# Epoch 114/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2653 - accuracy: 0.6645
# Epoch 115/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3185 - accuracy: 0.6184
# Epoch 116/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9852 - accuracy: 0.6776
# Epoch 117/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0489 - accuracy: 0.6645
# Epoch 118/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1205 - accuracy: 0.6776
# Epoch 119/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1541 - accuracy: 0.6776
# Epoch 120/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1267 - accuracy: 0.6776
# Epoch 121/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0140 - accuracy: 0.7039
# Epoch 122/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0808 - accuracy: 0.6447
# Epoch 123/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0805 - accuracy: 0.6908
# Epoch 124/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9094 - accuracy: 0.7171
# Epoch 125/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3407 - accuracy: 0.6250
# Epoch 126/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1114 - accuracy: 0.6645
# Epoch 127/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1464 - accuracy: 0.6645
# Epoch 128/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3733 - accuracy: 0.6513
# Epoch 129/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1055 - accuracy: 0.6711
# Epoch 130/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0300 - accuracy: 0.6447
# Epoch 131/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2403 - accuracy: 0.6250
# Epoch 132/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9708 - accuracy: 0.7039
# Epoch 133/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1423 - accuracy: 0.6974
# Epoch 134/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9774 - accuracy: 0.6974
# Epoch 135/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2526 - accuracy: 0.6776
# Epoch 136/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1098 - accuracy: 0.6382
# Epoch 137/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0272 - accuracy: 0.7105
# Epoch 138/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1406 - accuracy: 0.6513
# Epoch 139/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2267 - accuracy: 0.6579
# Epoch 140/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1199 - accuracy: 0.6513
# Epoch 141/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0692 - accuracy: 0.6711
# Epoch 142/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3212 - accuracy: 0.6711
# Epoch 143/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1973 - accuracy: 0.6382
# Epoch 144/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9552 - accuracy: 0.7105
# Epoch 145/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1394 - accuracy: 0.6579
# Epoch 146/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0980 - accuracy: 0.6974
# Epoch 147/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8889 - accuracy: 0.7566
# Epoch 148/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1279 - accuracy: 0.7039
# Epoch 149/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8543 - accuracy: 0.7171
# Epoch 150/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3857 - accuracy: 0.6447
# Epoch 151/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9695 - accuracy: 0.7105
# Epoch 152/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1263 - accuracy: 0.6645
# Epoch 153/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9904 - accuracy: 0.7303
# Epoch 154/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0147 - accuracy: 0.7171
# Epoch 155/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9998 - accuracy: 0.6908
# Epoch 156/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0005 - accuracy: 0.6842
# Epoch 157/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0711 - accuracy: 0.6908
# Epoch 158/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2753 - accuracy: 0.6974
# Epoch 159/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3039 - accuracy: 0.6711
# Epoch 160/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0354 - accuracy: 0.7368
# Epoch 161/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3669 - accuracy: 0.6645
# Epoch 162/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1477 - accuracy: 0.6842
# Epoch 163/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.5210 - accuracy: 0.6908
# Epoch 164/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9333 - accuracy: 0.7237
# Epoch 165/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9696 - accuracy: 0.6776
# Epoch 166/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2658 - accuracy: 0.7105
# Epoch 167/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3417 - accuracy: 0.6842
# Epoch 168/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2062 - accuracy: 0.6974
# Epoch 169/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9334 - accuracy: 0.7039
# Epoch 170/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.3595 - accuracy: 0.6711
# Epoch 171/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9793 - accuracy: 0.7105
# Epoch 172/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1658 - accuracy: 0.6382
# Epoch 173/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1387 - accuracy: 0.6776
# Epoch 174/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.1427 - accuracy: 0.6842
# Epoch 175/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9512 - accuracy: 0.6842
# Epoch 176/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0302 - accuracy: 0.6513
# Epoch 177/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0747 - accuracy: 0.6645
# Epoch 178/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0117 - accuracy: 0.7039
# Epoch 179/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9186 - accuracy: 0.7105
# Epoch 180/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1199 - accuracy: 0.6908
# Epoch 181/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1074 - accuracy: 0.6974
# Epoch 182/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2784 - accuracy: 0.6645
# Epoch 183/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0666 - accuracy: 0.7237
# Epoch 184/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0623 - accuracy: 0.6974
# Epoch 185/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1888 - accuracy: 0.6645
# Epoch 186/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9377 - accuracy: 0.7039
# Epoch 187/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8855 - accuracy: 0.7434
# Epoch 188/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1802 - accuracy: 0.6711
# Epoch 189/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1826 - accuracy: 0.6974
# Epoch 190/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2679 - accuracy: 0.6645
# Epoch 191/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2750 - accuracy: 0.6513
# Epoch 192/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1885 - accuracy: 0.6316
# Epoch 193/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9074 - accuracy: 0.6974
# Epoch 194/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0733 - accuracy: 0.7237
# Epoch 195/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0659 - accuracy: 0.6776
# Epoch 196/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3876 - accuracy: 0.6711
# Epoch 197/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1607 - accuracy: 0.6711
# Epoch 198/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2401 - accuracy: 0.7171
# Epoch 199/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2812 - accuracy: 0.7105
# Epoch 200/200
# 31/31 [==============================] - 0s 1ms/step - loss: 1.5982 - accuracy: 0.7039
# model is created
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/content/drive/MyDrive/Chatbot/intents.json').read())
words = pickle.load(open('/content/drive/MyDrive/Chatbot/words.pkl','rb'))
classes = pickle.load(open('/content/drive/MyDrive/Chatbot/classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
#from tensorflow.keras.optimizers import SGD
import tensorflow as tf
epochs = 200
learning_rate = 0.01
decay_rate = learning_rate / epochs
optimizer = tf.keras.optimizers.legacy.Adam(lr=learning_rate, decay=decay_rate)
import random

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
intents_file = open('/content/drive/MyDrive/Chatbot/intents.json').read()
intents = json.loads(intents_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=172, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [(['hi'], 'greeting'), (['hello'], 'greeting'), (['what', "'s", 'up'], 'greeting'), (['sup'], 'greeting'), (['is', 'anyone', 'there'], 'greeting'), (['whats', 'good'], 'greeting'), (['hey'], 'greeting'), (['How', "'s", 'the', 'day', 'treating', 'you', 'so', 'far', '?'], 'greeting'), (['bye'], 'goodbye'), (['cya'], 'goodbye'), (['see', 'you', 'later'], 'goodbye'), (['goodbye'], 'goodbye'), (['im', 'leaving'], 'goodbye'), (['have', 'a', 'good', 'day'], 'goodbye'), (['let', "'s", 'not', 'talk'], 'goodbye'), (['I', 'do', "n't", 'want', 'to', 'talk', 'to', 'you'], 'goodbye'), (['Who', 'is', 'your', 'creator'], 'creation'), (['Who', 'made', 'you'], 'creation'), (['who', 'built', 'you'], 'creation'), (['how', 'old', 'are', 'you', '?'], 'age'), (['what', 'is', 'your', 'age', '?'], 'age'), (['whats', 'your', 'age', '?'], 'age'), (['when', 'do', 'you', 'celebrate', 'your', 'birthday', '?'], 'age'), (['how', 'old', 'is', 'your', 'platform'], 'age'), (['ha', 'ha', 'ha', 'ha'], 'e_haha'), (['haha', 'haha', 'haha'], 'e_haha'), (['laughing', 'out'], 'e_haha'), (['hehehe'], 'e_haha'), (['ah', 'ah', 'ah'], 'e_haha'), (['thanks'], 'thanks'), (['thank', 'you'], 'thanks'), (['thankyou'], 'thanks'), (['ty'], 'thanks'), (['I', 'owe', 'you', 'one'], 'thanks'), (['whats', 'is', 'your', 'name'], 'name'), (['whats', 'your', 'name'], 'name'), (['whats', 'should', 'I', 'call', 'you'], 'name'), (['how', 'should', 'I', 'address', 'you'], 'name'), (['Yes', 'it', 'does'], 'yes'), (['Yeah'], 'yes'), (['Amazing'], 'yes'), (['Haha', 'yep'], 'yes'), (['fine'], 'yes'), (['yes'], 'yes'), (['Indeed'], 'yes'), (['Yup'], 'yes'), (['yep'], 'yes'), (['Oh', 'really'], 'yes'), (['Okay'], 'yes'), (['Okie'], 'yes'), (['Ok'], 'yes'), (['I', 'see'], 'yes'), (['why'], 'why'), (['what'], 'why'), (['whats', 'that'], 'why'), (['no'], 'no'), (['nah'], 'no'), (['not', 'really'], 'no'), (['thats', 'scary'], 'no'), (['singularity'], 'no'), (['what', 'are', 'you', 'doing', 'now', '?'], 'what_are_you_doing'), (['What', 'are', 'you', 'doing', '?'], 'what_are_you_doing'), (['what', 'you', 'doin'], 'what_are_you_doing'), (['how', 'are', 'you'], 'how_are_you'), (['how', 'are', 'you', 'doing'], 'how_are_you'), (['what', 'is', 'going', 'on'], 'how_are_you'), (['what', 'are', 'you', 'doing'], 'how_are_you'), (['fuck'], 'abusive'), (['fuck', 'you'], 'abusive'), (['fuck', 'off'], 'abusive'), (['fuck', 'yourself'], 'abusive'), (['I', 'am', 'doing', 'great'], 'doing_great'), (['I', 'am', 'well'], 'doing_great'), (['Im', 'great'], 'doing_great'), (['awesome'], 'doing_great'), (['happy'], 'doing_great'), (['better'], 'doing_great'), (['not', 'great'], 'doing_badly'), (['not', 'well'], 'doing_badly'), (['not', 'good'], 'doing_badly'), (['bad'], 'doing_badly'), (['badly'], 'doing_badly'), (['terrible'], 'doing_badly'), (['horrible'], 'doing_badly'), (['awful'], 'doing_badly'), (['sad'], 'doing_badly'), (['break'], 'doing_badly'), (['depressed'], 'doing_badly'), (['depression'], 'doing_badly'), (['wait', 'you', 'watch', 'Netflix'], 'netflix'), (['how', 'do', 'you', 'watch', 'Netflix'], 'netflix'), (['Netflix'], 'netflix'), (['I', 'love', 'to', 'watch', 'netflix'], 'netflix'), (['I', 'love', 'netflix', 'and', 'chill'], 'netflix'), (['how', 'can', 'you', 'run'], 'quick_run'), (['how', 'do', 'you', 'run'], 'quick_run'), (['how', 'run'], 'quick_run'), (['why', 'run'], 'quick_run'), (['run'], 'quick_run'), (['are', 'you', 'real'], 'real_bot'), (['are', 'you', 'human'], 'real_bot'), (['are', 'you', 'a', 'robot'], 'real_bot'), (['are', 'you', 'alive'], 'real_bot'), (['are', 'you', 'sentient'], 'real_bot'), (['are', 'you', 'conscious'], 'real_bot'), (['tell', 'me', 'joke'], 'joke'), (['yeah', 'sure', 'tell', 'me'], 'joke'), (['got', 'any', 'good', 'jokes'], 'joke'), (['got', 'jokes'], 'joke'), (['can', 'you', 'tell', 'joke'], 'joke'), (['tell', 'joke'], 'joke'), (['how', 'about', 'another', 'one'], 'joke'), (['joke'], 'joke'), (['cheer', 'me', 'up'], 'joke'), (['make', 'me', 'happy'], 'joke'), (['can', 'you' ...
# 152 documents
# 29 classes ['abusive', 'age', 'bad_joke', 'creation', 'doing_badly', 'doing_great', 'e_haha', 'facts', 'favorite_food', 'favorite_movie', 'favorite_show', 'good_joke', 'goodbye', 'greeting', 'hate', 'how_are_you', 'joke', 'like', 'love', 'name', 'netflix', 'no', 'quick_run', 'real_bot', 'thanks', 'what_are_you_doing', 'why', 'yes', 'your_thoughts']
# 158 unique lemmatized words ["'s", 'a', 'about', 'address', 'age', 'ah', 'alive', 'am', 'amazing', 'and', 'another', 'any', 'anyone', 'are', 'awesome', 'awful', 'bad', 'badly', 'best', 'better', 'birthday', 'break', 'built', 'bye', 'call', 'can', 'celebrate', 'cheer', 'chill', 'conscious', 'cool', 'creator', 'cya', 'day', 'depressed', 'depression', 'do', 'doe', 'doin', 'doing', 'dumb', 'fact', 'far', 'favorite', 'film', 'fine', 'food', 'friend', 'fuck', 'funny', 'going', 'good', 'goodbye', 'got', 'great', 'ha', 'haha', 'happy', 'hate', 'have', 'hehehe', 'hello', 'hey', 'hi', 'horrible', 'how', 'human', 'i', 'im', 'indeed', 'is', 'it', 'joke', 'know', 'later', 'laugh', 'laughing', 'leaving', 'let', 'like', 'love', 'made', 'make', 'me', 'mean', 'movie', 'my', "n't", 'nah', 'name', 'netflix', 'no', 'not', 'now', 'off', 'oh', 'ok', 'okay', 'okie', 'old', 'on', 'one', 'out', 'owe', 'platform', 'real', 'really', 'robot', 'run', 'sad', 'scary', 'see', 'sentient', 'should', 'show', 'singularity', 'so', 'stupid', 'sup', 'sure', 'surprise', 'talk', 'tell', 'terrible', 'thank', 'thanks', 'thankyou', 'that', 'thats', 'the', 'there', 'think', 'thought', 'to', 'trash', 'treating', 'tv', 'ty', 'up', 'very', 'wa', 'wait', 'want', 'watch', 'well', 'what', 'whats', 'when', 'who', 'why', 'wrong', 'yeah', 'yep', 'yes', 'you', 'your', 'yourself', 'yup']
# Training data created
# Epoch 1/172
# <ipython-input-22-2e66ab100968>:75: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# 31/31 [==============================] - 0s 2ms/step - loss: 3.3605 - accuracy: 0.0592
# Epoch 2/172
# 31/31 [==============================] - 0s 2ms/step - loss: 3.1094 - accuracy: 0.1118
# Epoch 3/172
# 31/31 [==============================] - 0s 2ms/step - loss: 2.6663 - accuracy: 0.2303
# Epoch 4/172
# 31/31 [==============================] - 0s 2ms/step - loss: 2.2847 - accuracy: 0.3750
# Epoch 5/172
# 31/31 [==============================] - 0s 2ms/step - loss: 1.8803 - accuracy: 0.4868
# Epoch 6/172
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6301 - accuracy: 0.5066
# Epoch 7/172
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4690 - accuracy: 0.5526
# Epoch 8/172
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1433 - accuracy: 0.6513
# Epoch 9/172
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1898 - accuracy: 0.6447
# Epoch 10/172
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1762 - accuracy: 0.6645
# Epoch 11/172
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0996 - accuracy: 0.6382
# Epoch 12/172
# 31/31 [==============================] - 0s 1ms/step - loss: 0.8843 - accuracy: 0.7303
# Epoch 13/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8262 - accuracy: 0.7434
# Epoch 14/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8236 - accuracy: 0.7039
# Epoch 15/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9128 - accuracy: 0.7303
# Epoch 16/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7343 - accuracy: 0.7763
# Epoch 17/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7672 - accuracy: 0.7961
# Epoch 18/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6255 - accuracy: 0.8026
# Epoch 19/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.8092
# Epoch 20/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.8421
# Epoch 21/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.7697
# Epoch 22/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6415 - accuracy: 0.8224
# Epoch 23/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.8355
# Epoch 24/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4954 - accuracy: 0.8750
# Epoch 25/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.8487
# Epoch 26/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5270 - accuracy: 0.8553
# Epoch 27/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6874 - accuracy: 0.8421
# Epoch 28/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.8421
# Epoch 29/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.8355
# Epoch 30/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.8026
# Epoch 31/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4623 - accuracy: 0.8684
# Epoch 32/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8226 - accuracy: 0.7829
# Epoch 33/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8618
# Epoch 34/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.7829
# Epoch 35/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4809 - accuracy: 0.8618
# Epoch 36/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6025 - accuracy: 0.8487
# Epoch 37/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6329 - accuracy: 0.8224
# Epoch 38/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.8684
# Epoch 39/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8421
# Epoch 40/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5694 - accuracy: 0.8224
# Epoch 41/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4856 - accuracy: 0.8421
# Epoch 42/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5375 - accuracy: 0.8158
# Epoch 43/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5260 - accuracy: 0.8553
# Epoch 44/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.8487
# Epoch 45/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4976 - accuracy: 0.8553
# Epoch 46/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.9013
# Epoch 47/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8816
# Epoch 48/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.8684
# Epoch 49/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.8618
# Epoch 50/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8882
# Epoch 51/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6781 - accuracy: 0.8158
# Epoch 52/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.8553
# Epoch 53/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5822 - accuracy: 0.8618
# Epoch 54/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4782 - accuracy: 0.8882
# Epoch 55/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.8553
# Epoch 56/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.8553
# Epoch 57/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8816
# Epoch 58/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8553
# Epoch 59/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5616 - accuracy: 0.8553
# Epoch 60/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.8421
# Epoch 61/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.8421
# Epoch 62/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5553 - accuracy: 0.8487
# Epoch 63/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4968 - accuracy: 0.8947
# Epoch 64/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.8618
# Epoch 65/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5751 - accuracy: 0.8289
# Epoch 66/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4220 - accuracy: 0.8618
# Epoch 67/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.8618
# Epoch 68/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3202 - accuracy: 0.8684
# Epoch 69/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5453 - accuracy: 0.8553
# Epoch 70/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7551 - accuracy: 0.8487
# Epoch 71/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5385 - accuracy: 0.8355
# Epoch 72/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4071 - accuracy: 0.8684
# Epoch 73/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7667 - accuracy: 0.8750
# Epoch 74/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.9013
# Epoch 75/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3577 - accuracy: 0.8947
# Epoch 76/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3381 - accuracy: 0.9013
# Epoch 77/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8882
# Epoch 78/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5535 - accuracy: 0.8618
# Epoch 79/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6613 - accuracy: 0.8026
# Epoch 80/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5069 - accuracy: 0.8158
# Epoch 81/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.8618
# Epoch 82/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8618
# Epoch 83/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3297 - accuracy: 0.9013
# Epoch 84/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8882
# Epoch 85/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8816
# Epoch 86/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8947
# Epoch 87/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3076 - accuracy: 0.8947
# Epoch 88/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.9013
# Epoch 89/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.8750
# Epoch 90/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.9211
# Epoch 91/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3015 - accuracy: 0.8947
# Epoch 92/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4957 - accuracy: 0.8816
# Epoch 93/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9408
# Epoch 94/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8816
# Epoch 95/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5993 - accuracy: 0.8750
# Epoch 96/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4258 - accuracy: 0.8816
# Epoch 97/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4940 - accuracy: 0.8421
# Epoch 98/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.8750
# Epoch 99/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.9013
# Epoch 100/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.9079
# Epoch 101/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2793 - accuracy: 0.9276
# Epoch 102/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.9145
# Epoch 103/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8947
# Epoch 104/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2651 - accuracy: 0.9079
# Epoch 105/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.8553
# Epoch 106/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8816
# Epoch 107/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3296 - accuracy: 0.9079
# Epoch 108/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2822 - accuracy: 0.9013
# Epoch 109/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.9211
# Epoch 110/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9539
# Epoch 111/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2389 - accuracy: 0.9211
# Epoch 112/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.9211
# Epoch 113/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8684
# Epoch 114/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9408
# Epoch 115/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1760 - accuracy: 0.9539
# Epoch 116/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3337 - accuracy: 0.9079
# Epoch 117/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.9013
# Epoch 118/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8882
# Epoch 119/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.9342
# Epoch 120/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.8816
# Epoch 121/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3157 - accuracy: 0.9342
# Epoch 122/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8947
# Epoch 123/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4739 - accuracy: 0.8882
# Epoch 124/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3080 - accuracy: 0.8947
# Epoch 125/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.9013
# Epoch 126/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4572 - accuracy: 0.8618
# Epoch 127/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4075 - accuracy: 0.9211
# Epoch 128/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.9342
# Epoch 129/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.9145
# Epoch 130/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.8618
# Epoch 131/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5539 - accuracy: 0.9013
# Epoch 132/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2809 - accuracy: 0.9211
# Epoch 133/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3941 - accuracy: 0.8947
# Epoch 134/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3849 - accuracy: 0.8816
# Epoch 135/172
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3456 - accuracy: 0.8947
# Epoch 136/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.9211
# Epoch 137/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8816
# Epoch 138/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.8750
# Epoch 139/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2978 - accuracy: 0.9013
# Epoch 140/172
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2928 - accuracy: 0.9211
# Epoch 141/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4769 - accuracy: 0.9145
# Epoch 142/172
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4607 - accuracy: 0.9013
# Epoch 143/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.9342
# Epoch 144/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.9079
# Epoch 145/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8816
# Epoch 146/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4378 - accuracy: 0.8882
# Epoch 147/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9211
# Epoch 148/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8750
# Epoch 149/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2873 - accuracy: 0.9013
# Epoch 150/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5484 - accuracy: 0.8684
# Epoch 151/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3220 - accuracy: 0.9079
# Epoch 152/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.8816
# Epoch 153/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 0.9079
# Epoch 154/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9474
# Epoch 155/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.9145
# Epoch 156/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.9013
# Epoch 157/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.9145
# Epoch 158/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2450 - accuracy: 0.9342
# Epoch 159/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8882
# Epoch 160/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.9079
# Epoch 161/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2976 - accuracy: 0.8947
# Epoch 162/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.8421
# Epoch 163/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2617 - accuracy: 0.9342
# Epoch 164/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.9145
# Epoch 165/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2884 - accuracy: 0.9211
# Epoch 166/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.8882
# Epoch 167/172
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3633 - accuracy: 0.8750
# Epoch 168/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.9079
# Epoch 169/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5340 - accuracy: 0.8618
# Epoch 170/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.8947
# Epoch 171/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.9079
# Epoch 172/172
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.9211
# model created

# %%
# !pip install ibm_watson
# Out:
# Collecting ibm_watson
#   Downloading ibm-watson-7.0.1.tar.gz (389 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.3/389.3 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (2.8.2)
# Requirement already satisfied: websocket-client>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ibm_watson) (1.6.4)
# Collecting ibm-cloud-sdk-core==3.*,>=3.3.6 (from ibm_watson)
#   Downloading ibm-cloud-sdk-core-3.17.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting urllib3<2.0.0,>=1.26.18 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 8.8 MB/s eta 0:00:00
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->ibm_watson) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->ibm_watson) (2023.7.22)
# Building wheels for collected packages: ibm_watson, ibm-cloud-sdk-core
#   Building wheel for ibm_watson (pyproject.toml) ... done
#   Created wheel for ibm_watson: filename=ibm_watson-7.0.1-py3-none-any.whl size=389785 sha256=ca62a2c087be333182afc28844a8694e619e3f3b3ec7d1c0113b56cec3b79425
#   Stored in directory: /root/.cache/pip/wheels/34/df/f4/f8edc5ba0637dd4bfb2029741ae20402976a49d1b6bc113553
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml) ... done
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.17.3-py3-none-any.whl size=87034 sha256=84f629d2f5bd9ec217570cc5d7afb8931f998ee548b182567964dc5ec099275e
#   Stored in directory: /root/.cache/pip/wheels/79/f8/2a/252525dc6e246fa21beb8f9d287d22dae8bd1036dc9dd9690d
# Successfully built ibm_watson ibm-cloud-sdk-core
# Installing collected packages: urllib3, PyJWT, ibm-cloud-sdk-core, ibm_watson
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# Successfully installed PyJWT-2.8.0 ibm-cloud-sdk-core-3.17.3 ibm_watson-7.0.1 urllib3-1.26.18

# %%
import anvil.server
#server connection
anvil.server.connect("FDFLEPPVIGZFNLYADVFLX4JQ-ZHXYWRBKP6XZYK2Q")

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions

msg = list()
text = str()


@anvil.server.callable
def responsed(msg1):
    msg.append(msg1)
    ints = predict_class(msg1)
    res = getResponse(ints, intents)
    return res

# %%
#Emotion API
@anvil.server.callable
def song_emotion():
    authenticator = IAMAuthenticator('w-xi_-3MuHXleSEg7zqpP7vify2N_LtyF5t7hlywxkkA')
    natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2022-04-07',
    authenticator=authenticator
    )

    natural_language_understanding.set_service_url('https://api.us-east.natural-language-understanding.watson.cloud.ibm.com/instances/ce5a8d62-bc63-41c1-9c15-a51b0f933126')
    len1 = len(msg)
    response = natural_language_understanding.analyze(
    text=msg[len1-1]+" "+msg[len1-2]+" "+msg[len1-3]+" "+msg[len1-4]+" "+msg[len1-5],
    features=Features(
        entities=EntitiesOptions(emotion=True, sentiment=True, limit=2),
        keywords=KeywordsOptions(emotion=True, sentiment=True, limit=2))
    ).get_result()
    dic1=dict()
    dic2=dict()
    dic2=response['keywords'][0]['emotion']
    dic1['emotion'] = max(zip(dic2.values(), dic2.keys()))[1]
    emotion = max(zip(dic2.values(), dic2.keys()))[1]
    print(dic1['emotion'])
    import requests

    url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={emotion}&api_key=670ed82a5251608fc1d95b1e15ae7c10&format=json&limit=10"
    response = requests.get(url)
    payload = response.json()
    for i in range(10):
        r=payload['tracks']['track'][i]
        dic1[r['name']] = r['url']
    return dic1

# %%
import requests

url=f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag=happy&api_key=670ed82a5251608fc1d95b1e15ae7c10&format=json&limit=5"
response = requests.get(url)
payload = response.json()
# for i in range(4):
r=payload['tracks']['track'][0]
# print(r['url'])
print(payload)
# Out:
# {'tracks': {'track': [{'name': 'Pumped Up Kicks', 'duration': '236', 'mbid': '816b3284-5f24-4f3a-9554-750e0bf5d060', 'url': 'https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Foster the People', 'mbid': 'e0e1a584-dd0a-4bd1-88d1-c4c62895039d', 'url': 'https://www.last.fm/music/Foster+the+People'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '1'}}, {'name': 'Dog Days Are Over', 'duration': '270', 'mbid': '772ea437-45b3-4868-b3c0-b80526ef0fa3', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine/_/Dog+Days+Are+Over', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Florence + the Machine', 'mbid': '5fee3020-513b-48c2-b1f7-4681b01db0c6', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '2'}}, {'name': "I'm Yours", 'duration': '242', 'mbid': 'a5a2330e-2fff-4601-a715-6e68a8e98fbf', 'url': 'https://www.last.fm/music/Jason+Mraz/_/I%27m+Yours', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'Jason Mraz', 'mbid': '82eb8936-7bf6-4577-8320-a2639465206d', 'url': 'https://www.last.fm/music/Jason+Mraz'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '3'}}, {'name': 'Hey Ya!', 'duration': '233', 'mbid': '2d753fb3-70c9-4499-beac-285c47fb5a1e', 'url': 'https://www.last.fm/music/OutKast/_/Hey+Ya%21', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'OutKast', 'mbid': '73fdb566-a9b1-494c-9f32-51768ec9fd27', 'url': 'https://www.last.fm/music/OutKast'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'large'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'extralarge'}], '@attr': {'rank': '4'}}, {'name': "Friday I'm in Love", 'duration': '214', 'mbid': '8d9104c6-7d8e-460b-8c3d-2d797f79953d', 'url': 'https://www.last.fm/music/The+Cure/_/Friday+I%27m+in+Love', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'artist': {'name': 'The Cure', 'mbid': '69ee3720-a7cb-4402-b48d-a02c366f2bcf', 'url': 'https://www.last.fm/music/The+Cure'}, 'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'small'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'size': 'medium'}, {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b ...

# %%
print("Chatbot : Hey there, Wassup ?")
# responded function takes text of user and returns chatbot output
for i in range(5):
    m = input("User : ")
    res = responsed(m)
    print("Chatbot : "+res)
ans = song_emotion()
print("Emotion : "+ans['emotion'])

# %%
# Suggesting songs
ans = song_emotion()
print("Emotion : "+ans['emotion'])
ans.pop('emotion')
lst = list(ans.keys())
print("Song Recommendations : ")
for i in range(len(lst)):
    print("Song_name : "+lst[i])
    print("Song_URL : "+ans[lst[i]])
